# %% [markdown]
# #  Importing Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# # Now let's read or load our first image.

# %% [markdown]
# # Use the function cv2.imread() to read and cv.imshow() to display an image.
# -> The image should be in the working directory or a full path of image should be given.

# %%
# Load an image using 'imread' specifying the path to image
img = cv2.imread('messi.jpg')

# Our file 'messi.jpg' is now loaded and stored in python as a varaible we named 'img'

# To display our image variable, we use 'imshow'
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# We can also use plt.imshow() to display an image.
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Lionel Messi")

plt.show()

# %%
img.shape
# Out:
# (408, 612, 3)

# %%
print("Height of the image : " , img.shape[0], "pixels")
print("Width of the image is : ", img.shape[1], "pixels")
# Out:
# Height of the image :  408 pixels
# Width of the image is :  612 pixels

# %% [markdown]
# # Use the function cv2.imwrite() to save an image.
# -> First argument is the file name, second argument is the image you want to save.
# -> This will save the image in PNG format in the working directory.

# %%
cv2.imwrite('messi_out.png',img)
# Out:
# True
